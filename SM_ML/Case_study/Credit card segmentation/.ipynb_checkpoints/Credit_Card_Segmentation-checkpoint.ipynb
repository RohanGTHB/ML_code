# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
#_________________________________
from sklearn import  metrics
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE,RFECV,SelectKBest
from sklearn.cluster import KMeans,DBSCAN
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %% [markdown]
# #### Dictionary
#
# - CUST_ID: Credit card holder ID
# - BALANCE: Monthly average balance (based on daily balance averages)
# - BALANCE_FREQUENCY: Ratio of last 12 months with balance
# - PURCHASES: Total purchase amount spent during last 12 months
# - ONEOFF_PURCHASES: Total amount of one-off purchases
# - INSTALLMENTS_PURCHASES: Total amount of installment purchases
# - CASH_ADVANCE: Total cash-advance amount
# - PURCHASES_ FREQUENCY: Frequency of purchases (Percent of months with at least onepurchase)
# - ONEOFF_PURCHASES_FREQUENCY: Frequency of one-off-purchases
# - PURCHASES_INSTALLMENTS_FREQUENCY: Frequency of installment purchases
# - CASH_ADVANCE_ FREQUENCY: Cash-Advance frequency
# - AVERAGE_PURCHASE_TRX: Average amount per purchase transaction
# - CASH_ADVANCE_TRX: Average amount per cash-advance transaction
# - PURCHASES_TRX: Average amount per purchase transaction
# - CREDIT_LIMIT: Credit limit
# - PAYMENTS: Total payments (due amount paid by the customer to decrease their statementbalance) in the period
# - MINIMUM_PAYMENTS: Total minimum payments due in the period.
# - PRC_FULL_PAYMEN: Percentage of months with full payment of the due statement balance
# - TENURE: Number of months as a customer

# %%
data = pd.read_csv('/home/rohan/Documents/ROHAN_DA/ALABS/___STATS___ -  cls 10 onwards/Class_20 Case_study_ML/Case_study/4. CREDIT CARD CASE STUDY - SEGMENTATION/CC GENERAL.csv')
data.head(2)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182       95.4               0.0
# 1  C10002  3202.467416           0.909091        0.0               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# 1                    0.25                 4              0        7000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12

# %% [markdown]
# - Columns with null values

# %% [raw]
# data[-data.CUST_ID.duplicated()] # unique values
# data[-data.CUST_ID.duplicated()] # duplicate values

# %%
data.loc[:,data.isnull().any()].isnull().sum()
# Out:
# CREDIT_LIMIT          1
# MINIMUM_PAYMENTS    313
# dtype: int64

# %%
#data.describe(include='all').T
data.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# PURCHASES_TRX                     8950.0    14.709832    24.857649   0.000000
# CREDIT_LIMIT                      8949.0  4494.449450  3638.815725  50.000000
# PAYMENTS                          8950.0  1733.143852  2895.063757   0.000000
# MINIMUM_PAYMENTS                  8637.0   864.206542  2372.446607   0.019163
# PRC_FULL_PAYMENT                  8950.0     0.153715     0.292499   0.000000
# TENURE                            8950.0    11.517318     1.338331   6.000000
#
#                                           25%          50%          75%  \
# BALANCE                            128.281915   873.385231  2054.140036
# BALANCE_FREQUENCY                    0.888889     1.000000     1.000000
# PURCHASES                           39.635000   361.280000  1110.130000
# ONEOFF_PURCHASES                     0.000000    38.000000   577.405000
# INSTALLMENTS_PURCHASES               0.000000    89.000000   468.637500
# CASH_ADVANCE                         0.000000     0.000000  1113.821139
# PURCHASES_FREQUENCY                  0.083333     0.500000     0.916667
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.083333     0.300000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.166667     0.750000
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.222222
# CASH_ADVANCE_TRX                     0.000000     0.000000     4.000000
# PURCHASES_TRX                        1.000000     7.000000    17.000000
# CREDIT_LIMIT                      1600.000000  3000.000000  6500.000000
# PAYMENTS                           383.276166   856.901546  1901.134317
# MINIMUM_PAYMENTS                   169.123707   312.343947   825.485459
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.142857
# TENURE                              12.000000    12.000000    12.000000
#
#                                           max
# BALANCE                           19043.13856
# BALANCE_FREQUENCY                     1.00000
# PURCHASES                         49039.57000
# ONEOFF_PURCHASES                  40761.25000
# INSTALLMENTS_PURCHASES            22500.00000
# CASH_ADVANCE                      47137.21176
# PURCHASES_FREQUENCY                   1.00000
# ONEOFF_PURCHASES_FREQUENCY            1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY      1.00000
# CASH_ADVANCE_FREQUENCY                1.50000
# CASH_ADVANCE_TRX                    123.00000
# PURCHASES_TRX                       358.00000
# CREDIT_LIMIT                      30000.00000
# PAYMENTS                          50721.48336
# MINIMUM_PAYMENTS                  76406.20752
# PRC_FULL_PAYMENT                      1.00000
# TENURE                               12.00000

# %% [markdown]
# - No. of Zeroes in the dataset

# %%
df = pd.DataFrame()
for x in data.columns:
    y = data[data[x] == 0].shape[0]
    df = df.append({'col_name':x,'zeros':y},ignore_index=True)
df
# Out:
#                             col_name   zeros
# 0                            CUST_ID     0.0
# 1                            BALANCE    80.0
# 2                  BALANCE_FREQUENCY    80.0
# 3                          PURCHASES  2044.0
# 4                   ONEOFF_PURCHASES  4302.0
# 5             INSTALLMENTS_PURCHASES  3916.0
# 6                       CASH_ADVANCE  4628.0
# 7                PURCHASES_FREQUENCY  2043.0
# 8         ONEOFF_PURCHASES_FREQUENCY  4302.0
# 9   PURCHASES_INSTALLMENTS_FREQUENCY  3915.0
# 10            CASH_ADVANCE_FREQUENCY  4628.0
# 11                  CASH_ADVANCE_TRX  4628.0
# 12                     PURCHASES_TRX  2044.0
# 13                      CREDIT_LIMIT     0.0
# 14                          PAYMENTS   240.0
# 15                  MINIMUM_PAYMENTS     0.0
# 16                  PRC_FULL_PAYMENT  5903.0
# 17                            TENURE     0.0

# %%
data.head(2)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182       95.4               0.0
# 1  C10002  3202.467416           0.909091        0.0               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# 1                    0.25                 4              0        7000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12

# %% [markdown]
# ### Feature Selection
#
# - `purchase` = one_off + installment --> we can discard (purchase & purchase frequency)
#     - Also can be seen in correl plot that one_off & install are correl to purchase
# - `install to one_off` = we can take the differ. to captur the imapact
# - `cash_advance` is the cash taken out from card
# - `cust_id` = has to be removed

# %%
plt.figure(figsize=(15,11))
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# - Dropping the purchase & purchase_frequency

# %%
#data.drop(columns=['PURCHASES','PURCHASES_FREQUENCY','CUST_ID'],inplace= True)

# %% [markdown]
# - Treating the missing values

# %%
data.loc[:,data.isnull().any()].isnull().sum()
# Out:
# CREDIT_LIMIT          1
# MINIMUM_PAYMENTS    313
# dtype: int64

# %% [markdown]
# ### Fixing the min_payments
#
# - Looking how's it related to a few other variables
#
# - Based on the analysis shown, we can consider a direct relation bw `min_payment` & `Balance` are somehow directly related(though the slope is varying)
# - Based on the correlation matrix we can say that the `min_payment` & `Balance` are related

# %%
plt.figure(figsize=(8,8))


plt.scatter(x=data.MINIMUM_PAYMENTS,y=data.CREDIT_LIMIT,label='credit_Lim')

plt.scatter(x=data.MINIMUM_PAYMENTS,y=data.PAYMENTS,label='Payments')

plt.scatter(x=data.MINIMUM_PAYMENTS,y=data.BALANCE, label = 'Balance')

plt.axis('scaled')
plt.legend()


#---------------------------------------------------------------

plt.figure(figsize=(15,10))
plt.subplot(131)
plt.scatter(x=data.MINIMUM_PAYMENTS,y=data.CREDIT_LIMIT)
plt.xlabel('MINIMUM_PAYMENTS')
plt.ylabel('Credit_limit')
plt.axis('scaled')

plt.subplot(132)
plt.scatter(x=data.MINIMUM_PAYMENTS,y=data.PAYMENTS)
plt.xlabel('MINIMUM_PAYMENTS')
plt.ylabel('payments')
plt.axis('scaled')

plt.subplot(133)
plt.scatter(x=data.MINIMUM_PAYMENTS,y=data.BALANCE)
plt.xlabel('MINIMUM_PAYMENTS')
plt.ylabel('Balance')
plt.axis('scaled')
# MINIMUM_PAYMENTS

plt.tight_layout()

# %% [markdown]
# - Calculating the slopes categories
#
# - we can see that the majority of slopes lie in 0.2 - 0.5 range

# %%
t = data.loc[data.MINIMUM_PAYMENTS.notnull(),'MINIMUM_PAYMENTS']/data.loc[data.BALANCE != 0,'BALANCE']
tf = pd.cut(t,[0,0.2,0.35,0.5,1,10,100],labels=[1,2,3,4,5,6])
tf.value_counts()
# labels=['H','M',"L",'VL']
# Out:
# 2    3025
# 5    2271
# 4    1467
# 3    1407
# 6     305
# 1     144
# dtype: int64

# %%
0.35*data.BALANCE.mean(),data.MINIMUM_PAYMENTS.mean()
# Out:
# (547.5661896873363, 864.2065423050814)

# %% [markdown]
# - **Missing value treatment**
# - Out of both the above values we are taking the mean value

# %%
data.MINIMUM_PAYMENTS.fillna(data.MINIMUM_PAYMENTS.mean(),inplace=True)

# %%
# dropping the row with missing Credit Limit
data.dropna(axis =0,inplace=True)

# %%
data.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
data.head(2)
# Out:
#        BALANCE  BALANCE_FREQUENCY  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# 0    40.900749           0.818182               0.0                    95.4
# 1  3202.467416           0.909091               0.0                     0.0
#
#    CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0      0.000000                         0.0                          0.083333
# 1   6442.945483                         0.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# 1                    0.25                 4              0        7000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12

# %% [markdown]
# #### BoxPlot for outlier treatment
#
# - As can be seen, a lot of outliers exist, Fixing them

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data,orient='h')

# %%
data.describe(percentiles=[.05,.25,.5,.75,.95]).T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8949.0  1564.647593  2081.584016   0.000000
# BALANCE_FREQUENCY                 8949.0     0.877350     0.236798   0.000000
# ONEOFF_PURCHASES                  8949.0   592.503572  1659.968851   0.000000
# INSTALLMENTS_PURCHASES            8949.0   411.113579   904.378205   0.000000
# CASH_ADVANCE                      8949.0   978.959616  2097.264344   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8949.0     0.202480     0.298345   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8949.0     0.364478     0.397451   0.000000
# CASH_ADVANCE_FREQUENCY            8949.0     0.135141     0.200132   0.000000
# CASH_ADVANCE_TRX                  8949.0     3.249078     6.824987   0.000000
# PURCHASES_TRX                     8949.0    14.711476    24.858552   0.000000
# CREDIT_LIMIT                      8949.0  4494.449450  3638.815725  50.000000
# PAYMENTS                          8949.0  1733.336511  2895.168146   0.000000
# MINIMUM_PAYMENTS                  8949.0   864.301501  2330.700932   0.019163
# PRC_FULL_PAYMENT                  8949.0     0.153732     0.292511   0.000000
# TENURE                            8949.0    11.517935     1.337134   6.000000
#
#                                            5%          25%          50%  \
# BALANCE                              8.813965   128.365782   873.680279
# BALANCE_FREQUENCY                    0.272727     0.888889     1.000000
# ONEOFF_PURCHASES                     0.000000     0.000000    38.000000
# INSTALLMENTS_PURCHASES               0.000000     0.000000    89.000000
# CASH_ADVANCE                         0.000000     0.000000     0.000000
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.000000     0.083333
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.000000     0.166667
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.000000
# CASH_ADVANCE_TRX                     0.000000     0.000000     0.000000
# PURCHASES_TRX                        0.000000     1.000000     7.000000
# CREDIT_LIMIT                      1000.000000  1600.000000  3000.000000
# PAYMENTS                            90.111420   383.282850   857.062706
# MINIMUM_PAYMENTS                    74.679795   170.875613   335.657631
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.000000
# TENURE                               8.000000    12.000000    12.000000
#
#                                           75%           95%          max
# BALANCE                           2054.372848   5909.377888  19043.13856
# BALANCE_FREQUENCY                    1.000000      1.000000      1.00000
# ONEOFF_PURCHASES                   577.830000   2671.528000  40761.25000
# INSTALLMENTS_PURCHASES             468.650000   1750.420000  22500.00000
# CASH_ADVANCE                      1113.868654   4647.894019  47137.21176
# ONEOFF_PURCHASES_FREQUENCY           0.300000      1.000000      1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.750000      1.000000      1.00000
# CASH_ADVANCE_FREQUENCY               0.222222      0.583333      1.50000
# CASH_ADVANCE_TRX                     4.000000     15.000000    123.00000
# PURCHASES_TRX                       17.000000     57.000000    358.00000
# CREDIT_LIMIT                      6500.000000  12000.000000  30000.00000
# PAYMENTS                          1901.279320   6082.239054  50721.48336
# MINIMUM_PAYMENTS                   864.206542   2719.861546  76406.20752
# PRC_FULL_PAYMENT                     0.142857      1.000000      1.00000
# TENURE                              12.000000     12.000000     12.00000

# %% [markdown]
# - Starting with **DBScan** without outlier treatment since it can treat outliers on its own

# %%
sc = StandardScaler()
data_sc = sc.fit_transform(data)
# Out:
# /home/rohan/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/rohan/anaconda3/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# #### Loop for DBscan params

# %%
df = pd.DataFrame(index=np.arange(0,15))
for x in [.5,1,1.5,2,2.5]:
    for y in [6,8,10,12]:
        dbs = DBSCAN(eps = x,min_samples= y)
        dbs.fit(data_sc)
        label_count = pd.Series(dbs.labels_)
        vc = label_count.value_counts()
        #vc_cent = vc.apply(lambda x:round(x*100/vc.sum()))
        vc_cent = pd.DataFrame(vc,columns=['eps:{0}_minpoint:{1}'.format(x,y)])
        df = df.merge(vc_cent,how='outer',left_index=True,right_index=True)

# %%
df.T
# Out:
#                         -1       0      1     2     3     4     5     6   \
# eps:0.5_minpoint:6   6547.0  2075.0    8.0   6.0  14.0  21.0  14.0  10.0
# eps:0.5_minpoint:8   6852.0  1638.0  235.0  16.0  13.0   8.0  23.0  13.0
# eps:0.5_minpoint:10  7035.0  1581.0  220.0  22.0  26.0  20.0  25.0  10.0
# eps:0.5_minpoint:12  7139.0  1529.0  207.0  22.0  26.0  13.0  13.0   NaN
# eps:1_minpoint:6     2959.0  5913.0   31.0   8.0   6.0  13.0   6.0   6.0
# eps:1_minpoint:8     3171.0  5701.0   14.0  11.0  24.0   6.0  13.0   9.0
# eps:1_minpoint:10    3382.0  5539.0   14.0  14.0   NaN   NaN   NaN   NaN
# eps:1_minpoint:12    3528.0  5385.0   36.0   NaN   NaN   NaN   NaN   NaN
# eps:1.5_minpoint:6   1208.0  7725.0   10.0   6.0   NaN   NaN   NaN   NaN
# eps:1.5_minpoint:8   1297.0  7644.0    8.0   NaN   NaN   NaN   NaN   NaN
# eps:1.5_minpoint:10  1380.0  7562.0    7.0   NaN   NaN   NaN   NaN   NaN
# eps:1.5_minpoint:12  1444.0  7505.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2_minpoint:6      565.0  8384.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2_minpoint:8      597.0  8352.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2_minpoint:10     634.0  8315.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2_minpoint:12     666.0  8283.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2.5_minpoint:6    319.0  8630.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2.5_minpoint:8    330.0  8619.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2.5_minpoint:10   351.0  8598.0    NaN   NaN   NaN   NaN   NaN   NaN
# eps:2.5_minpoint:12   359.0  8590.0    NaN   NaN   NaN   NaN   NaN   NaN
#
#                        7     8  ...    14    15   16   17    18   19   20  \
# eps:0.5_minpoint:6    9.0  39.0 ...   5.0   9.0  5.0  6.0  23.0  6.0  6.0
# eps:0.5_minpoint:8   10.0   8.0 ...   8.0  10.0  8.0  3.0   6.0  NaN  NaN
# eps:0.5_minpoint:10  10.0   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:0.5_minpoint:12   NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1_minpoint:6      7.0   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1_minpoint:8      NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1_minpoint:10     NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1_minpoint:12     NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1.5_minpoint:6    NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1.5_minpoint:8    NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1.5_minpoint:10   NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:1.5_minpoint:12   NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2_minpoint:6      NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2_minpoint:8      NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2_minpoint:10     NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2_minpoint:12     NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2.5_minpoint:6    NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2.5_minpoint:8    NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2.5_minpoint:10   NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
# eps:2.5_minpoint:12   NaN   NaN ...   NaN   NaN  NaN  NaN   NaN  NaN  NaN
#
#                        21   22   23
# eps:0.5_minpoint:6   10.0  6.0  3.0
# eps:0.5_minpoint:8    NaN  NaN  NaN
# eps:0.5_minpoint:10   NaN  NaN  NaN
# eps:0.5_minpoint:12   NaN  NaN  NaN
# eps:1_minpoint:6      NaN  NaN  NaN
# eps:1_minpoint:8      NaN  NaN  NaN
# eps:1_minpoint:10     NaN  NaN  NaN
# eps:1_minpoint:12     NaN  NaN  NaN
# eps:1.5_minpoint:6    NaN  NaN  NaN
# eps:1.5_minpoint:8    NaN  NaN  NaN
# eps:1.5_minpoint:10   NaN  NaN  NaN
# eps:1.5_minpoint:12   NaN  NaN  NaN
# eps:2_minpoint:6      NaN  NaN  NaN
# eps:2_minpoint:8      NaN  NaN  NaN
# eps:2_minpoint:10     NaN  NaN  NaN
# eps:2_minpoint:12     NaN  NaN  NaN
# eps:2.5_minpoint:6    NaN  NaN  NaN
# eps:2.5_minpoint:8    NaN  NaN  NaN
# eps:2.5_minpoint:10   NaN  NaN  NaN
# eps:2.5_minpoint:12   NaN  NaN  NaN
#
# [20 rows x 25 columns]

# %% [markdown]
# - From here we can do 2 things,
#
#
# 1. outlier_treatment & then try `kmeans` & see if we should go with 2 or 3 clusters
# 2. build the model using DBscan 2 combinations ( 1 with 2 features & other with 3 features) & compare the means

# %%
# 3 cluster combination
DBS_2 = DBSCAN(eps=1,min_samples=12).fit(data_sc)

# 2 cluster combination
DBS_3 =DBSCAN(eps=0.5,min_samples=12).fit(data_sc)

# %%
# Conactenating labels found through DBScan with data 

# save the cluster labels and sort by cluster
data['cluster_2'] = DBS_2.labels_
data['cluster_3'] = DBS_3.labels_
# telco_num['cluster_5'] = km_5.labels_
# telco_num['cluster_6'] = km_6.labels_
# telco_num['cluster_7'] = km_7.labels_
# telco_num['cluster_8'] = km_8.labels_

# %%
data.cluster_2.value_counts()
# Out:
#  0    5385
# -1    3528
#  1      36
# Name: cluster_2, dtype: int64

# %%
size=pd.concat([pd.Series(data.cluster_2.size),pd.Series.sort_index(data.cluster_2.value_counts()),
                pd.Series.sort_index(data.cluster_3.value_counts())])
size
# Out:
#  0    8949
# -1    3528
#  0    5385
#  1      36
# -1    7139
#  0    1529
#  1     207
#  2      22
#  3      26
#  4      13
#  5      13
# dtype: int64

# %% [markdown]
# - `Seg_size` captures the number of variables in each clusters
# - `Seg_Pct` captures the % repr of obs in each cluster

# %%
Seg_size=pd.DataFrame(size, columns=['Seg_size'])
Seg_Pct = pd.DataFrame(size/data.cluster_3.size, columns=['Seg_Pct'])
Seg_size.T
# Out:
#              0    -1     0   1    -1     0    1   2   3   4   5
# Seg_size  8949  3528  5385  36  7139  1529  207  22  26  13  13

# %%
Seg_Pct.T
# Out:
#            0        -1         0         1        -1         0         1  \
# Seg_Pct  1.0  0.394234  0.601743  0.004023  0.797743  0.170857  0.023131
#
#                 2         3         4         5
# Seg_Pct  0.002458  0.002905  0.001453  0.001453

# %%
data.head(2)
# Out:
#        BALANCE  BALANCE_FREQUENCY  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# 0    40.900749           0.818182               0.0                    95.4
# 1  3202.467416           0.909091               0.0                     0.0
#
#    CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0      0.000000                         0.0                          0.083333
# 1   6442.945483                         0.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# 1                    0.25                 4              0        7000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster_2  \
# 0   201.802084        139.509787          0.000000      12          0
# 1  4103.032597       1072.340217          0.222222      12         -1
#
#    cluster_3
# 0         -1
# 1         -1

# %%
# Mean value gives a good indication of the distribution of data. So we are finding mean value for each variable for each cluster
Profling_output = pd.concat([data.apply(lambda x: x.mean()).T,
                             data.groupby('cluster_2').apply(lambda x: x.mean()).T, 
                             data.groupby('cluster_3').apply(lambda x: x.mean()).T], axis=1)

Profling_output_final=pd.concat([Seg_size.T, Seg_Pct.T, Profling_output], axis=0)
#Profling_output_final.columns = ['Seg_' + str(i) for i in Profling_output_final.columns]
Profling_output_final.columns = ['Overall', 'DBS2_1', 'DBS2_2','DBS2_3', 'DBS3_1',
                                 'DBS3_2', 'DBS3_3','DBS3_4','DBS3_5','DBS3_6','DBS3_7']

# %%
Profling_output_final
# Out:
#                                       Overall       DBS2_1       DBS2_2  \
# Seg_size                          8949.000000  3528.000000  5385.000000
# Seg_Pct                              1.000000     0.394234     0.601743
# BALANCE                           1564.647593  2472.324984   979.853508
# BALANCE_FREQUENCY                    0.877350     0.894740     0.865272
# ONEOFF_PURCHASES                   592.503572  1207.045119   187.736117
# INSTALLMENTS_PURCHASES             411.113579   715.305031   214.464299
# CASH_ADVANCE                       978.959616  1847.481072   416.480688
# ONEOFF_PURCHASES_FREQUENCY           0.202480     0.343806     0.104884
# PURCHASES_INSTALLMENTS_FREQUENCY     0.364478     0.435372     0.320345
# CASH_ADVANCE_FREQUENCY               0.135141     0.210293     0.086792
# CASH_ADVANCE_TRX                     3.249078     5.714853     1.655153
# PURCHASES_TRX                       14.711476    25.557823     7.606314
# CREDIT_LIMIT                      4494.449450  6552.357561  3139.904064
# PAYMENTS                          1733.336511  3210.397201   770.774581
# MINIMUM_PAYMENTS                   864.301501  1470.453178   471.809964
# PRC_FULL_PAYMENT                     0.153732     0.185915     0.127428
# TENURE                              11.517935    11.195578    11.725905
# cluster_2                           -0.390211    -1.000000     0.000000
# cluster_3                           -0.747905    -1.000000    -0.581058
#
#                                        DBS2_3       DBS3_1       DBS3_2  \
# Seg_size                            36.000000  7139.000000  1529.000000
# Seg_Pct                              0.004023     0.797743     0.170857
# BALANCE                             87.711832  1760.777847   930.622289
# BALANCE_FREQUENCY                    0.979798     0.875886     0.996849
# ONEOFF_PURCHASES                   913.897222   725.373324    64.647443
# INSTALLMENTS_PURCHASES              15.806111   484.361755   131.691138
# CASH_ADVANCE                         1.329877  1175.683261   233.410357
# ONEOFF_PURCHASES_FREQUENCY           0.951389     0.243311     0.040495
# PURCHASES_INSTALLMENTS_FREQUENCY     0.018519     0.387257     0.295782
# CASH_ADVANCE_FREQUENCY               0.002315     0.152034     0.080227
# CASH_ADVANCE_TRX                     0.027778     3.795490     1.281884
# PURCHASES_TRX                       14.583333    17.255358     5.017659
# CREDIT_LIMIT                      5436.868687  5101.621347  2033.060824
# PAYMENTS                           964.610870  2049.071466   515.447081
# MINIMUM_PAYMENTS                   171.629647   983.470372   412.375478
# PRC_FULL_PAYMENT                     0.934386     0.172478     0.074397
# TENURE                              12.000000    11.395714    12.000000
# cluster_2                            1.000000    -0.489144     0.000000
# cluster_3                           -1.000000    -1.000000     0.000000
#
#                                        DBS3_3       DBS3_4       DBS3_5  \
# Seg_size                           207.000000    22.000000    26.000000
# Seg_Pct                              0.023131     0.002458     0.002905
# BALANCE                             25.630971     0.034974    16.133056
# BALANCE_FREQUENCY                    0.257795     0.008264     0.297202
# ONEOFF_PURCHASES                   116.962899     2.075000    28.707692
# INSTALLMENTS_PURCHASES              34.025169   267.800000   168.230385
# CASH_ADVANCE                         0.908233     0.000000     0.000000
# ONEOFF_PURCHASES_FREQUENCY           0.059984     0.003788     0.019231
# PURCHASES_INSTALLMENTS_FREQUENCY     0.060789     0.988636     0.195513
# CASH_ADVANCE_FREQUENCY               0.000805     0.000000     0.000000
# CASH_ADVANCE_TRX                     0.009662     0.000000     0.000000
# PURCHASES_TRX                        1.801932    12.000000     3.230769
# CREDIT_LIMIT                      2648.067633  2081.818182  2375.128205
# PAYMENTS                           324.951238   237.506637   585.420271
# MINIMUM_PAYMENTS                   278.717587   787.016012   150.685479
# PRC_FULL_PAYMENT                     0.003601     0.000000     1.000000
# TENURE                              12.000000    12.000000    12.000000
# cluster_2                            0.000000     0.000000     0.000000
# cluster_3                            1.000000     2.000000     3.000000
#
#                                        DBS3_6       DBS3_7
# Seg_size                            13.000000    13.000000
# Seg_Pct                              0.001453     0.001453
# BALANCE                            226.344461    19.112389
# BALANCE_FREQUENCY                    0.440559     0.559441
# ONEOFF_PURCHASES                     0.000000     1.923077
# INSTALLMENTS_PURCHASES               0.000000   194.792308
# CASH_ADVANCE                       802.643368     0.000000
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.006410
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.416667
# CASH_ADVANCE_FREQUENCY               0.089743     0.000000
# CASH_ADVANCE_TRX                     1.384615     0.000000
# PURCHASES_TRX                        0.000000     5.692308
# CREDIT_LIMIT                      1207.692308  1569.230769
# PAYMENTS                           274.427840   300.777589
# MINIMUM_PAYMENTS                   209.081711   113.251065
# PRC_FULL_PAYMENT                     0.000000     0.302359
# TENURE                              12.000000    12.000000
# cluster_2                            0.000000     0.000000
# cluster_3                            4.000000     5.000000

# %%
#Profling_output_final.to_csv('/home/rohan/Desktop/Profling_output_final')

# %%
from IPython.display import Image
Image("/home/rohan/Desktop/jupyter/ROHAN_ALL/SM_&_ML/Case_study/Credit card segmentation/Screenshot from 2019-03-05 00-58-23.png")

# %% [markdown]
# - **Conclusion**
#
# - DBS2 serves well in making judgement
#
# - DBS2_1 - higher credit limit + risky customers + Moneymaking customers + 3.5k customers
# - DBS2_2 - lower crefit limit + safe players + low spenders
#
#
# #### Verdict
# - Based on the above analysis DBS_1 customers can be targeted with cross sell & other related product offerings while we can pause the extra cutomers benfits to DBS2_2 customers as these are anyway not spending much & are also not defaulting on anything

# %% [markdown]
# ### Clustering Using `KMeans`

# %% [markdown]
# Since KMeans is a technique that gets affected by outliers present, thats why we are clipping the outliers values first before building the model

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data,orient='h')

# %%
data.describe(percentiles=[.03,.05,.25,.5,.75,.95,.97]).T
# Out:
#                                    count         mean          std  \
# BALANCE                           8949.0  1498.881103  1820.975270
# BALANCE_FREQUENCY                 8949.0     0.879867     0.228463
# ONEOFF_PURCHASES                  8949.0   484.830997   866.478129
# INSTALLMENTS_PURCHASES            8949.0   356.610350   560.609346
# CASH_ADVANCE                      8949.0   870.782275  1514.828153
# ONEOFF_PURCHASES_FREQUENCY        8949.0     0.202480     0.298345
# PURCHASES_INSTALLMENTS_FREQUENCY  8949.0     0.364478     0.397451
# CASH_ADVANCE_FREQUENCY            8949.0     0.130859     0.185501
# CASH_ADVANCE_TRX                  8949.0     2.888479     4.777793
# PURCHASES_TRX                     8949.0    13.392558    17.899467
# CREDIT_LIMIT                      8949.0  4420.899333  3344.836284
# PAYMENTS                          8949.0  1555.785580  1848.286382
# MINIMUM_PAYMENTS                  8949.0   684.223050   826.503972
# PRC_FULL_PAYMENT                  8949.0     0.153732     0.292511
# TENURE                            8949.0    11.540619     1.248892
# cluster_2                         8949.0    -0.394234     0.488713
# cluster_3                         8949.0    -0.766343     0.491822
#
#                                           min           3%           5%  \
# BALANCE                              4.387025     4.388724     8.813965
# BALANCE_FREQUENCY                    0.181818     0.181818     0.272727
# ONEOFF_PURCHASES                     0.000000     0.000000     0.000000
# INSTALLMENTS_PURCHASES               0.000000     0.000000     0.000000
# CASH_ADVANCE                         0.000000     0.000000     0.000000
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.000000     0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.000000     0.000000
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.000000
# CASH_ADVANCE_TRX                     0.000000     0.000000     0.000000
# PURCHASES_TRX                        0.000000     0.000000     0.000000
# CREDIT_LIMIT                      1000.000000  1000.000000  1000.000000
# PAYMENTS                            28.457827    28.501301    90.111420
# MINIMUM_PAYMENTS                    55.379492    55.393254    74.679795
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.000000
# TENURE                               7.000000     7.000000     8.000000
# cluster_2                           -1.000000    -1.000000    -1.000000
# cluster_3                           -1.000000    -1.000000    -1.000000
#
#                                           25%          50%          75%  \
# BALANCE                            128.365782   873.680279  2054.372848
# BALANCE_FREQUENCY                    0.888889     1.000000     1.000000
# ONEOFF_PURCHASES                     0.000000    38.000000   577.830000
# INSTALLMENTS_PURCHASES               0.000000    89.000000   468.650000
# CASH_ADVANCE                         0.000000     0.000000  1113.868654
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.083333     0.300000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.166667     0.750000
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.222222
# CASH_ADVANCE_TRX                     0.000000     0.000000     4.000000
# PURCHASES_TRX                        1.000000     7.000000    17.000000
# CREDIT_LIMIT                      1600.000000  3000.000000  6500.000000
# PAYMENTS                           383.282850   857.062706  1901.279320
# MINIMUM_PAYMENTS                   170.875613   335.657631   864.206542
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.142857
# TENURE                              12.000000    12.000000    12.000000
# cluster_2                           -1.000000     0.000000     0.000000
# cluster_3                           -1.000000    -1.000000    -1.000000
#
#                                            95%           97%           max
# BALANCE                            5909.377888   7083.425360   7085.196339
# BALANCE_FREQUENCY                     1.000000      1.000000      1.000000
# ONEOFF_PURCHASES                   2671.528000   3609.666496   3610.001600
# INSTALLMENTS_PURCHASES             1750.420000   2273.062240   2273.284000
# CASH_ADVANCE                       4647.894019   6005.440264   6011.667259
# ONEOFF_PURCHASES_FREQUENCY            1.000000      1.000000      1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY      1.000000      1.000000      1.000000
# CASH_ADVANCE_FREQUENCY                0.583333      0.666667      0.666667
# CASH_ADVANCE_TRX                     15.000000     19.000000     19.000000
# PURCHASES_TRX                        57.000000     75.000000     75.000000
# CREDIT_LIMIT                      12000.000000  13500.000000  13500.000000
# PAYMENTS                           6082.239054   8081.143852   8085.321541
# MINIMUM_PAYMENTS                   2719.861546   3656.994544   3658.876109
# PRC_FULL_PAYMENT                      1.000000      1.000000      1.000000
# TENURE                               12.000000     12.000000     12.000000
# cluster_2                             0.000000      0.000000      0.000000
# cluster_3                             0.000000      1.000000      1.000000

# %%
data = data.apply(lambda x:x.clip_lower(x.quantile(0.03)))
data = data.apply(lambda x:x.clip_upper(x.quantile(0.97)))

# %% [markdown]
# #### Analysing the SC value & Elbow curve

# %%
cluster_range = range( 1, 20 )
cluster_errors = []

for num_clusters in cluster_range:
    clusters = KMeans(num_clusters)
    clusters.fit( data_sc )
    cluster_errors.append( clusters.inertia_ )

# %%
clusters_df = pd.DataFrame( { "num_clusters":cluster_range, "cluster_errors": cluster_errors } )

clusters_df[0:10]
# Out:
#    num_clusters  cluster_errors
# 0             1   134235.000000
# 1             2   114795.487986
# 2             3    99526.917351
# 3             4    91860.881640
# 4             5    84748.263165
# 5             6    78663.090611
# 6             7    72943.256841
# 7             8    69409.777789
# 8             9    64818.231369
# 9            10    61144.224756

# %%
# allow plots to appear in the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.plot( clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" )
plt.xlabel('no of clusters',fontsize = 20)
plt.ylabel('inertia:Error',fontsize = 20)
# Out:
# Text(0,0.5,'inertia:Error')

# %% [markdown]
# ### Silhouette Coefficient

# %%
# calculate SC for K=2 through K=12
k_range = range(2, 12)
scores = []
for k in k_range:
    km = KMeans(n_clusters=k, random_state=1)
    km.fit(data_sc)
    scores.append(metrics.silhouette_score(data_sc, km.labels_))

# %%
scores
# Out:
# [0.32932885839313825,
#  0.27433275478666236,
#  0.15748185251840616,
#  0.17688694126236387,
#  0.18661147730646227,
#  0.20377507589614516,
#  0.20711884495738012,
#  0.2056997757145927,
#  0.20998076281920222,
#  0.20651177795606676]

# %%
# plot the results
plt.figure(figsize=(6,4))
plt.plot(k_range, scores)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Coefficient')
plt.grid(True)

# %% [markdown]
# #### Conclusion
#
# - Based on the above curves we can conclude that the best params for clustering could be
# - n = 2 or maybe 3 , Most prob 2!

# %%
km_2 =  KMeans(n_clusters=2)
km_2.fit(data_sc)

pd.Series(km_2.labels_).value_counts()
# Out:
# 0    7273
# 1    1676
# dtype: int64

# %%
km_3 =  KMeans(n_clusters=3)
km_3.fit(data_sc)

pd.Series(km_3.labels_).value_counts()
# Out:
# 2    6268
# 0    1527
# 1    1154
# dtype: int64

# %%
data['cluster_2'] = km_2.labels_
data['cluster_3'] = km_3.labels_

# %%
size=pd.concat([pd.Series(data.cluster_3.size),
                pd.Series.sort_index(data.cluster_2.value_counts()), 
                pd.Series.sort_index(data.cluster_3.value_counts())])

# %%
Seg_size=pd.DataFrame(size, columns=['Seg_size'])
Seg_Pct = pd.DataFrame(size/data.cluster_3.size, columns=['Seg_Pct'])
Seg_size.T
# Out:
#              0     0     1     0     1     2
# Seg_size  8949  7273  1676  1527  1154  6268

# %%
Seg_Pct.T
# Out:
#            0         0         1         0         1         2
# Seg_Pct  1.0  0.812717  0.187283  0.170634  0.128953  0.700413

# %%
# Mean value gives a good indication of the distribution of data. So we are finding mean value for each variable for each cluster
Profling_output = pd.concat([data.apply(lambda x: x.mean()).T, data.groupby('cluster_2').apply(lambda x: x.mean()).T, 
                             data.groupby('cluster_3').apply(lambda x: x.mean()).T], axis=1)

Profling_output_final=pd.concat([Seg_size.T, Seg_Pct.T, Profling_output], axis=0)
Profling_output_final
# Out:
#                                             0            0            1  \
# Seg_size                          8949.000000  7273.000000  1676.000000
# Seg_Pct                              1.000000     0.812717     0.187283
# BALANCE                           1498.881103   878.755791  4189.914153
# BALANCE_FREQUENCY                    0.879867     0.859096     0.970000
# ONEOFF_PURCHASES                   484.830997   428.112836   730.959387
# INSTALLMENTS_PURCHASES             356.610350   336.129019   445.489063
# CASH_ADVANCE                       870.782275   365.017419  3065.548261
# ONEOFF_PURCHASES_FREQUENCY           0.202480     0.193928     0.239592
# PURCHASES_INSTALLMENTS_FREQUENCY     0.364478     0.375469     0.316784
# CASH_ADVANCE_FREQUENCY               0.130859     0.074981     0.373338
# CASH_ADVANCE_TRX                     2.888479     1.376186     9.451074
# PURCHASES_TRX                       13.392558    12.440533    17.523866
# CREDIT_LIMIT                      4420.899333  3656.066766  7739.889347
# PAYMENTS                          1555.785580  1148.937892  3321.300639
# MINIMUM_PAYMENTS                   684.223050   484.121894  1552.561778
# PRC_FULL_PAYMENT                     0.153732     0.176647     0.054292
# TENURE                              11.540619    11.533755    11.570406
# cluster_2                            0.187283     0.000000     1.000000
# cluster_3                            1.529780     1.830744     0.223747
#
#                                             0            1            2
# Seg_size                          1527.000000  1154.000000  6268.000000
# Seg_Pct                              0.170634     0.128953     0.700413
# BALANCE                           3851.847519  2052.154054   823.792286
# BALANCE_FREQUENCY                    0.963262     0.981231     0.840888
# ONEOFF_PURCHASES                   285.770024  1966.629993   260.512245
# INSTALLMENTS_PURCHASES             166.217878  1168.149683   253.581141
# CASH_ADVANCE                      3388.055784   356.659852   352.183141
# ONEOFF_PURCHASES_FREQUENCY           0.126162     0.684194     0.132385
# PURCHASES_INSTALLMENTS_FREQUENCY     0.176226     0.747335     0.339852
# CASH_ADVANCE_FREQUENCY               0.433010     0.052994     0.071585
# CASH_ADVANCE_TRX                    10.822528     1.141248     1.277281
# PURCHASES_TRX                        6.819253    47.997400     8.622846
# CREDIT_LIMIT                      6754.587129  7565.294627  3273.456220
# PAYMENTS                          2685.644895  3501.938095   922.225406
# MINIMUM_PAYMENTS                  1388.657232   830.102308   485.752141
# PRC_FULL_PAYMENT                     0.034931     0.309128     0.154064
# TENURE                              11.421742    11.930676    11.497766
# cluster_2                            0.865750     0.288562     0.003350
# cluster_3                            0.000000     1.000000     2.000000

# %% [markdown]
# - As can be seen only 2 clusters are relevant where each cluster represent the following:
#         - cluster_1 : High spenders + high Credit limit + revenue generating + risky
#         - cluster_2 : Low spenders + medium/low credit limit + safe players + less risky
