# %% [markdown]
# #### Importing Library

# %%
import pandas as pd
import scipy.stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#_________________________________

from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn import metrics
import pandas_profiling
# Out:
# /home/rohan/anaconda3/lib/python3.6/site-packages/pandas_profiling/plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/rohan/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/rohan/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/rohan/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/rohan/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/rohan/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-53d74b1518a1>", line 4, in <module>
#     import matplotlib.pyplot as plt
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/home/rohan/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)

# %% [markdown]
# #### Loading Datasets

# %%
Active =  pd.read_excel('/home/rohan/Documents/ROHAN_DA/ALABS/___STATS___ -  cls 10 onwards/Class_20 Case_study_ML/Case_study/5. TELECOM CASE STUDY - SEGMENTATION-CLASSIFICATION/Case_study_data.xlsx',sheet_name=
                     0)
churn = pd.read_excel('/home/rohan/Documents/ROHAN_DA/ALABS/___STATS___ -  cls 10 onwards/Class_20 Case_study_ML/Case_study/5. TELECOM CASE STUDY - SEGMENTATION-CLASSIFICATION/Case_study_data.xlsx',sheet_name=
                     1)

# %% [markdown]
# #### Analysing DS

# %%
Active.shape
# Out:
# (9999, 29)

# %%
Active.head(2)
# Out:
#   SITE_ACCOUNT_NUMBER ACCOUNT_STATUS  FIRST_COMMUNICATION_DATE  UPGRADE_DATE  \
# 0        AMR-11112345         Active                   37222.0       37969.0
# 1        AMR-14837287         Active                   37743.0       38937.0
#
#   SERVICE_PLAN    MODEL SALES_CHANNEL DIRECT_INDIRECT_CHANNEL SALES_SOURCE  \
# 0          NaN   HN9000          Vars                Indirect      UNKNOWN
# 1          Pro  HN7000S  Sales Agents                Indirect          NCC
#
#   COMPANY_SOURCE_NAME      ...          SITE_TYPE_DESC WARRANTY_NAME  \
# 0       HNS Customers      ...        Broadband Remote             0
# 1       HNS Customers      ...                Spaceway             0
#
#   MOST_RECENT_SALES_CHANNEL GENDER DATE_OF_BIRTH AGE INCOME MARITAL_STATUS  \
# 0            HN7000 Upgrade    2.0      1-5-1943  69      0            1.0
# 1             Retail           2.0    28-12-1969  43      4            1.0
#
#   PRESENCE_OF_CHILDREN COMPUTER_OWNER
# 0                  0.0              N
# 1                  0.0              N
#
# [2 rows x 29 columns]

# %%
Churn.head(2)
# Out:
#   SITE_ACCOUNT_NUMBER ACCOUNT_STATUS  FIRST_COMMUNICATION_DATE  CHURN_DATE  \
# 0        AMR-53205840         Closed                     37274       38809
# 1        AMR-53383136         Closed                     37258       38907
#
#    UPGRADE_DATE  SERVICE_PLAN   MODEL  SALES_CHANNEL DIRECT_INDIRECT_CHANNEL  \
# 0       37989.0  Professional  DW6000            NaN                Indirect
# 1       38196.0            SO  DW6000  Retail/Others                Indirect
#
#        SALES_SOURCE      ...          SITE_TYPE_DESC WARRANTY_NAME  \
# 0        Perfect 10      ...        Broadband Remote           NaN
# 1  ValueElectronics      ...        Broadband Remote           NaN
#
#   MOST_RECENT_SALES_CHANNEL GENDER DATE_OF_BIRTH   AGE INCOME MARITAL_STATUS  \
# 0     Dealer-Generated Sale    2.0    27-10-1964  48.0      0              .
# 1            National Sales    NaN    22-10-1965  47.0      5              0
#
#   PRESENCE_OF_CHILDREN COMPUTER_OWNER
# 0                  NaN              N
# 1                  0.0              Y
#
# [2 rows x 30 columns]

# %%
Churn.shape
# Out:
# (10000, 30)

# %% [markdown]
# #### Difference(columns) in Active & churn customers
#
# - Only `Churn Date` is extra in Churn

# %%
# np.intersect1d(Active.columns,Churn.columns)
list(np.setdiff1d(Active.columns,Churn.columns))
# Out:
# []

# %%
list(np.setdiff1d(Churn.columns,Active.columns))
# Out:
# ['CHURN_DATE']

# %% [markdown]
# ## Feature Engg

# %% [markdown]
# ### Analysis - S1
#
# - `ADDRESS` has a high cardinality: 9911 distinct values Warning - Drop -> Done
# - `AGE` has a high cardinality: 64 distinct values Warning - Fine
# - `CITY` has a high cardinality: 829 distinct values Warning - Fine
# - `COMPUTER_OWNER` has 3055 / 30.6% missing values Missing - Drop -> Done
# - `DATE_OF_BIRTH` has a high cardinality: 7188 distinct values Warning - drop -> Done
# - `EMAIL_ADDRESS` has a high cardinality: 9927 distinct values Warning - drop -> Done
# - `FEEDBACK` has 1914 / 19.1% missing values Missing - fix it()
# - `FIRST_NAME` has a high cardinality: 577 distinct values Warning - keep
# - `GENDER` has 1271 / 12.7% missing values Missing - fix
# - `INCOME` has 318 / 3.2% missing values Missing - fix
# - `LAST_NAME` has a high cardinality: 879 distinct values Warning - fine
# - `MARITAL_STATUS` has 4654 / 46.5% zeros Zeros -> Drop - Done
# - `MARITAL_STATUS` has 319 / 3.2% missing values Missing -> Drop - Done
# - `MODEL` has 676 / 6.8% missing values Missing - fix it
# - `PRESENCE_OF_CHILDREN` has 6643 / 66.4% zeros Zeros - drop -> Done
# - `PRESENCE_OF_CHILDREN` has 1315 / 13.2% missing values Missing - drop -> Done
# - `SALES_CHANNEL` has 2906 / 29.1% missing values Missing - how bought
# - `SALES_SOURCE` has 693 / 6.9% missing values Missing - dealer
# - `SATELLITE` has 396 / 4.0% missing values Missing - fix
# - `SERVICE_ PLAN` has 1239 / 12.4% missing values Missing - fix
# - `WARRANTY_NAME` has 957 / 9.6% missing values Missing - fix
# - `ZIPCODE` has a high cardinality: 897 distinct values Warning - fine

# %%
pandas_profiling.ProfileReport(Active)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>24 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>9827 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.8 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>192.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>19 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_AGE"><code>AGE</code></a> has a high cardinality: 63 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CITY"><code>CITY</code></a> has a high cardinality: 826 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_COMPANY_SOURCE_NAME"><code>COMPANY_SOURCE_NAME</code></a> has constant value HNS Customers <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_FIRST_NAME"><code>FIRST_NAME</code></a> has a high cardinality: 576 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_LAST_NAME"><code>LAST_NAME</code></a> has a high cardinality: 878 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_UPGRADE_DATE"><code>UPGRADE_DATE</code></a> is highly correlated with <a href="#pp_var_FIRST_COMMUNICATION_DATE"><code>FIRST_COMMUNICATION_DATE</code></a> (ρ = 0.99449) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_ZIPCODE"><code>ZIPCODE</code></a> has a high cardinality: 896 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlig

# %% [markdown]
# #### Dropping all variables' null rows which have less than 100 null values

# %%
Active.isnull().sum().sort_values(ascending =  False)
# Out:
# COMPUTER_OWNER               3055
# SALES_CHANNEL                2906
# FEEDBACK                     1914
# PRESENCE_OF_CHILDREN         1315
# GENDER                       1271
# SERVICE_PLAN                 1239
# WARRANTY_NAME                 957
# SALES_SOURCE                  693
# MODEL                         676
# SATELLITE                     396
# MARITAL_STATUS                319
# INCOME                        318
# ADDRESS                        54
# DIRECT_INDIRECT_CHANNEL        45
# STATE                          22
# ZIPCODE                        22
# EMAIL_ADDRESS                  20
# COMPANY_SOURCE_NAME            11
# SITE_TYPE_DESC                 11
# UPGRADE_DATE                   10
# FIRST_COMMUNICATION_DATE       10
# MOST_RECENT_SALES_CHANNEL       7
# CITY                            1
# LAST_NAME                       1
# FIRST_NAME                      1
# DATE_OF_BIRTH                   1
# AGE                             1
# ACCOUNT_STATUS                  1
# SITE_ACCOUNT_NUMBER             1
# dtype: int64

# %% [markdown]
# - Columns with less than 100 null values

# %%
Active[Active.columns[Active.isnull().sum() < 100]].columns
# Out:
# Index(['SITE_ACCOUNT_NUMBER', 'ACCOUNT_STATUS', 'FIRST_COMMUNICATION_DATE',
#        'UPGRADE_DATE', 'DIRECT_INDIRECT_CHANNEL', 'COMPANY_SOURCE_NAME',
#        'FIRST_NAME', 'LAST_NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIPCODE',
#        'EMAIL_ADDRESS', 'SITE_TYPE_DESC', 'MOST_RECENT_SALES_CHANNEL',
#        'DATE_OF_BIRTH', 'AGE'],
#       dtype='object')

# %% [markdown]
# -  Dropping NA rows for columns with < 100 null values

# %%
Active.dropna(subset= Active[Active.columns[Active.isnull().sum() < 100]].columns,inplace=True)

# %% [markdown]
# #### After Dropping the rows

# %%
Active.isnull().sum().sort_values(ascending =  False)
# Out:
# COMPUTER_OWNER               2982
# SALES_CHANNEL                2855
# FEEDBACK                     1875
# PRESENCE_OF_CHILDREN         1280
# GENDER                       1254
# SERVICE_PLAN                 1209
# WARRANTY_NAME                 934
# SALES_SOURCE                  683
# MODEL                         657
# SATELLITE                     380
# MARITAL_STATUS                315
# INCOME                        303
# FIRST_COMMUNICATION_DATE        0
# UPGRADE_DATE                    0
# FIRST_NAME                      0
# ACCOUNT_STATUS                  0
# DIRECT_INDIRECT_CHANNEL         0
# COMPANY_SOURCE_NAME             0
# STATE                           0
# LAST_NAME                       0
# ADDRESS                         0
# CITY                            0
# ZIPCODE                         0
# EMAIL_ADDRESS                   0
# SITE_TYPE_DESC                  0
# MOST_RECENT_SALES_CHANNEL       0
# DATE_OF_BIRTH                   0
# AGE                             0
# SITE_ACCOUNT_NUMBER             0
# dtype: int64

# %%
pandas_profiling.ProfileReport(Active)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>30 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>9827 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>5.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>2.2 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>240.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>22 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_ADDRESS"><code>ADDRESS</code></a> has a high cardinality: 9795 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_AGE"><code>AGE</code></a> has a high cardinality: 63 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CITY"><code>CITY</code></a> has a high cardinality: 826 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_COMPANY_SOURCE_NAME"><code>COMPANY_SOURCE_NAME</code></a> has constant value HNS Customers <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_COMPUTER_OWNER"><code>COMPUTER_OWNER</code></a> has 2982 / 30.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_DATE_OF_BIRTH"><code>DATE_OF_BIRTH</code></a> has a high cardinality: 7096 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_EMAIL_ADDRESS"><code>EMAIL_ADDRESS</code></a> has a high cardinality: 9777 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_FEEDBACK"><code>FEEDBACK</code></a> has 1875 / 19.1% missing values <span class="label label-default">Missing</spa

# %% [markdown]
# ### Applying corrective measures based on Analysis done earlier - Pandas Profiling - S2

# %% [markdown]
# #### Dropping `ADDRESS`,`COMPUTER_OWNER`,`DATE_OF_BIRTH`,`EMAIL_ADDRESS`,`PRESENCE_OF_CHILDREN` columns
#
# - This is based on the results obtained from pandas profiling

# %%
Active.drop(columns=['ADDRESS','COMPUTER_OWNER','DATE_OF_BIRTH','EMAIL_ADDRESS','PRESENCE_OF_CHILDREN','MARITAL_STATUS'],inplace=True)

# %%
Active.shape
# Out:
# (9827, 23)

# %% [markdown]
# #### Fixing the remaining columns

# %%
cols = ['FEEDBACK','GENDER','INCOME','MODEL','SALES_CHANNEL','SALES_SOURCE',
        'SATELLITE','SERVICE_PLAN','WARRANTY_NAME']
for x in cols:
    print(Active[x].value_counts(dropna = False))
# Out:
# GOOD    4943
# BAD     3009
# NaN     1875
# Name: FEEDBACK, dtype: int64
#  1.0    4682
#  2.0    3891
# NaN     1254
# Name: GENDER, dtype: int64
# 0      2687
# 6      1510
# 7       998
# 4       950
# 5       866
# 3       664
# 8       586
# 9       459
# NaN     303
# A       189
# 2       168
# 1       155
# D       154
# C        96
# B        42
# Name: INCOME, dtype: int64
# HN7000S    4221
# HN9000     1960
# UNK         956
# NaN         657
# DW4020      648
# DW4000      631
# DW6000      506
# DW7000      248
# Name: MODEL, dtype: int64
# NaN              2855
# Sales Agents     1430
# Retail/others    1415
# Vars             1395
# Web orders       1369
# Call Center      1363
# Name: SALES_CHANNEL, dtype: int64
# TAG                                        1684
# Hughes Web Order                           1359
# RS&I                                       1042
# Perfect 10                                  841
# AmericanSat                                 802
# NaN                                         683
# NCC                                         582
# ACS                                         428
# LiveBridge Communications LLC               428
# InfoDish                                    360
# ACS Pre-Install                             292
# UNKNOWN                                     288
# Best Buy                                    287
# Verisign Web Ordering                       239
# MiniDish                                    119
# ValueElectronics                             92
# NRTC                                         62
# PEGASUS BROADBAND COMMUNICATIO               62
# PEGASUS                                      33
# D&H DISTRIBUTING                             25
# OROURKE BROTHERS                             16
# Hughes Internal Sales                        16
# Skylink (RSI572499)                          12
# Ridgeline USA LLC (RSI573306)                12
# Alpha Satellite (RSI568059)                  10
# Skylink                                      10
# SKYWALKER COMMUNICATIONS                     10
# Todays TV                                    10
# 0                                            10
# J & L AND SONS CUSTOM INSTALLATIONS INC       7
# Professional Satellites                       6
# Name: SALES_SOURCE, dtype: int64
# SPACEWAY3       1360
# SM5-VER-5K       874
# 0                828
# SM5-VER-15K      809
# G17-HOR-6K       705
# AM6-HOR-21K      658
# G17-HOR-2K       637
# SM5-VER-1K       552
# SM5-HOR-6K       417
# SM5-VER-7K       387
# NaN              380
# AM9-VER-2K       350
# SM5-HOR-14K      338
# HZN2-VER-4K      250
# G16-VER-15K      143
# G3C-VER-21K       98
# G16-VER-1K        78
# G16-HOR-8K        75
# HZN2-VER-8K       67
# G3C-VER-24K       67
# AM9-HOR-21K       60
# AM32-HOR-19K      54
# HZN-HOR-8K        50
# HZN-HOR-19K       49
# HZN-VER-23K       48
# G3C-VER-9K        42
# G16-VER-21K       42
# AM9-HOR-17K       34
# HZN-VER-6K        31
# G16-HOR-2K        31
# HZN2-VER-5K       31
# SM6-HOR-13K       29
# SM6-HOR-12K       27
# SM6-VER-2K        26
# AM32-HOR-7K       26
# AM9-HOR-19K       23
# G16-VER-2K        23
# HZN-VER-11K       22
# AM9-VER-22K       19
# G28-HOR-16K       17
# G26-HOR-14K       16
# AMC-HOR-10K       13
# G28-HOR-10K       12
# SM6-HOR-10K       12
# AM9-VER-2K         9
# AMC-VER-5K         8
# Name: SATELLITE, dtype: int64
# Proplus      1253
# Basic_Ltd    1248
# Basic        1239
# Elite        1236
# Power150     1231
# Home         1223
# NaN          1209
# Pro          1188
# Name: SERVICE_PLAN, dtype: int64
# 0                                                8379
# NaN                                               934
# EXPRESS REPAIR HOME WITH TERM                     292
# EXPRESS REPAIR HOME WITH COMMITMENT WITH TERM      50
# EXPRESS REPAIR BASIC                               48
# EXPRESS REPAIR HOME                                43
# EXPRESS REPAIR BUSINESS WITH TERM                  37
# EXPRESS REPAIR HOME W/O COMMITMENT WITH TERM       20
# SRVC ASSUR STD EXISTING CUST NO COMMIT             17
# SRVC ASSUR STD NEW CUST                             7
# Name: WARRANTY_NAME, dtype: int64

# %%
cols = ['FEEDBACK','GENDER','INCOME','MODEL','SALES_CHANNEL','SALES_SOURCE',
        'SATELLITE','SERVICE_PLAN','WARRANTY_NAME']

def cat_imputer(DF,column):
    for x in cols:
        DF['{0}'.format(x)] = DF['{0}'.format(x)].fillna(pd.Series(np.random.choice(DF['{0}'.format(x)].value_counts().index.tolist(), 
                                                          p= DF['{0}'.format(x)].value_counts(normalize= True).values.tolist(), size=len(DF))))

        DF['{0}'.format(x)] = DF['{0}'.format(x)].fillna(method = 'ffill')
        DF['{0}'.format(x)] = DF['{0}'.format(x)].apply(str)

# %%
cat_imputer(Active,cols)

# %%
for x in cols:
    print(Active[x].value_counts())
# Out:
# GOOD    6093
# BAD     3734
# Name: FEEDBACK, dtype: int64
# 1.0    5361
# 2.0    4466
# Name: GENDER, dtype: int64
# 0    2779
# 6    1560
# 7    1034
# 4     982
# 5     887
# 3     689
# 8     605
# 9     471
# A     194
# 2     171
# 1     157
# D     156
# C      99
# B      43
# Name: INCOME, dtype: int64
# HN7000S    4546
# HN9000     2093
# UNK        1018
# DW4020      698
# DW4000      678
# DW6000      529
# DW7000      265
# Name: MODEL, dtype: int64
# Sales Agents     2017
# Retail/others    1975
# Web orders       1957
# Vars             1947
# Call Center      1931
# Name: SALES_CHANNEL, dtype: int64
# TAG                                        1819
# Hughes Web Order                           1461
# RS&I                                       1109
# Perfect 10                                  896
# AmericanSat                                 859
# NCC                                         627
# ACS                                         454
# LiveBridge Communications LLC               453
# InfoDish                                    394
# ACS Pre-Install                             320
# Best Buy                                    312
# UNKNOWN                                     304
# Verisign Web Ordering                       256
# MiniDish                                    134
# ValueElectronics                             98
# NRTC                                         69
# PEGASUS BROADBAND COMMUNICATIO               67
# PEGASUS                                      39
# D&H DISTRIBUTING                             27
# Hughes Internal Sales                        18
# OROURKE BROTHERS                             18
# Skylink (RSI572499)                          12
# Ridgeline USA LLC (RSI573306)                12
# SKYWALKER COMMUNICATIONS                     12
# 0                                            12
# Todays TV                                    12
# Alpha Satellite (RSI568059)                  10
# Skylink                                      10
# J & L AND SONS CUSTOM INSTALLATIONS INC       7
# Professional Satellites                       6
# Name: SALES_SOURCE, dtype: int64
# SPACEWAY3       1422
# SM5-VER-5K       909
# 0                854
# SM5-VER-15K      826
# G17-HOR-6K       734
# AM6-HOR-21K      676
# G17-HOR-2K       667
# SM5-VER-1K       578
# SM5-HOR-6K       438
# SM5-VER-7K       401
# AM9-VER-2K       369
# SM5-HOR-14K      353
# HZN2-VER-4K      267
# G16-VER-15K      152
# G3C-VER-21K      101
# G16-VER-1K        83
# G16-HOR-8K        81
# G3C-VER-24K       71
# HZN2-VER-8K       69
# AM9-HOR-21K       62
# AM32-HOR-19K      56
# HZN-HOR-19K       51
# HZN-HOR-8K        50
# HZN-VER-23K       50
# G3C-VER-9K        43
# G16-VER-21K       42
# AM9-HOR-17K       34
# HZN-VER-6K        32
# G16-HOR-2K        32
# HZN2-VER-5K       31
# SM6-HOR-13K       30
# SM6-HOR-12K       28
# AM32-HOR-7K       28
# SM6-VER-2K        26
# AM9-HOR-19K       24
# HZN-VER-11K       23
# G16-VER-2K        23
# AM9-VER-22K       20
# G28-HOR-16K       18
# G26-HOR-14K       16
# AMC-HOR-10K       13
# SM6-HOR-10K       13
# G28-HOR-10K       12
# AM9-VER-2K        11
# AMC-VER-5K         8
# Name: SATELLITE, dtype: int64
# Power150     1421
# Basic_Ltd    1420
# Proplus      1418
# Elite        1410
# Basic        1409
# Home         1394
# Pro          1355
# Name: SERVICE_PLAN, dtype: int64
# 0                                                9251
# EXPRESS REPAIR HOME WITH TERM                     334
# EXPRESS REPAIR HOME WITH COMMITMENT WITH TERM      56
# EXPRESS REPAIR BASIC                               50
# EXPRESS REPAIR HOME                                47
# EXPRESS REPAIR BUSINESS WITH TERM                  43
# EXPRESS REPAIR HOME W/O COMMITMENT WITH TERM       20
# SRVC ASSUR STD EXISTING CUST NO COMMIT             18
# SRVC ASSUR STD NEW CUST                             8
# Name: WARRANTY_NAME, dtype: int64

# %%
### Checking for remaining changes req - S3

# %% [markdown]
# #### Correl bw UPGRADE_DATE & FIRST_COMMUNICATION_DATE

# %%
pd.DataFrame(np.corrcoef(Active.UPGRADE_DATE,Active.FIRST_COMMUNICATION_DATE),
             columns= ['upgrade','first_Comm_date'])
# Out:
#     upgrade  first_Comm_date
# 0  1.000000         0.994485
# 1  0.994485         1.000000

# %%
plt.figure(figsize=[7,2])
x = Active[['UPGRADE_DATE','FIRST_COMMUNICATION_DATE']]
x.apply(lambda x:pd.to_datetime(x))

plt.plot(Active.UPGRADE_DATE)
plt.plot(Active.FIRST_COMMUNICATION_DATE)
plt.ylim(35000,50000)
# Out:
# (35000, 50000)

# %% [markdown]
# #### Dropping Cols

# %% [markdown]
# - `COMPANY_SOURCE_NAME` has constant value HNS Customers Rejected - drop - done
# - `UPGRADE_DATE` is highly correlated with FIRST_COMMUNICATION_DATE (ρ = 0.99449) Rejected
# - `ZIPCODE` has a high cardinality: 896 distinct values Warning - drop - done
#
# - `WARRANTY_NAME` has 9260 values as 0 - drop - done

# %%
Active.drop(columns= ['COMPANY_SOURCE_NAME','ZIPCODE','WARRANTY_NAME','UPGRADE_DATE'],inplace=True)

# %%
Active.shape
# Out:
# (9827, 19)

# %%
pandas_profiling.ProfileReport(Active)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>20 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>9827 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>160.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_AGE"><code>AGE</code></a> has a high cardinality: 63 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CITY"><code>CITY</code></a> has a high cardinality: 826 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_FIRST_NAME"><code>FIRST_NAME</code></a> has a high cardinality: 576 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_LAST_NAME"><code>LAST_NAME</code></a> has a high cardinality: 878 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_ACCOUNT_STATUS">ACCOUNT_STATUS<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>2</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0

# %% [markdown]
# #### Outliers
#
# - All columns are categorical (nominal or ordinal) in nature so outlier detection in not an issue

# %% [markdown]
# #### Correlation

# %% [markdown]
# - Using Chi Square test for correlation

# %%
def chi_p_val(DF):
    li = []
    lt = []
    for x in DF.columns:
        scipy.stats.chisquare(DF[x].value_counts())
        for y in DF.columns:
            if x != y:
                f = x,y
                lt.append([x,y])
                con = pd.crosstab(DF[x],DF[y])
                chi_stat,p_value,Dof,cont_table = scipy.stats.chi2_contingency(con)
                li.extend([p_value])
            else:
                pass
    chi_P_value = pd.DataFrame(np.vstack(lt),columns=['1st_col','2nd_col'])

    chi_P_value['chi_square_p_value'] = li
    return chi_P_value

# %%
final = chi_p_val(Active)
final.head(2)
# Out:
#                1st_col                   2nd_col  chi_square_p_value
# 0  SITE_ACCOUNT_NUMBER            ACCOUNT_STATUS            0.495257
# 1  SITE_ACCOUNT_NUMBER  FIRST_COMMUNICATION_DATE            0.448114

# %% [markdown]
# - Dependent Pair of vars for significane level of 0.05

# %%
final[final.chi_square_p_value < 0.05].sort_values(by = 'chi_square_p_value',ascending=False).head()
# Out:
#                      1st_col                  2nd_col  chi_square_p_value
# 259           SITE_TYPE_DESC             SALES_SOURCE            0.038049
# 139             SALES_SOURCE           SITE_TYPE_DESC            0.038049
# 118  DIRECT_INDIRECT_CHANNEL                    STATE            0.036169
# 204                    STATE  DIRECT_INDIRECT_CHANNEL            0.036169
# 124  DIRECT_INDIRECT_CHANNEL                      AGE            0.026047

# %%
final[final.chi_square_p_value < 0.05]['1st_col'].value_counts()
# Out:
# MOST_RECENT_SALES_CHANNEL    8
# AGE                          8
# SALES_SOURCE                 8
# SATELLITE                    8
# DIRECT_INDIRECT_CHANNEL      8
# MODEL                        7
# ACCOUNT_STATUS               6
# CITY                         4
# FEEDBACK                     4
# SITE_TYPE_DESC               4
# STATE                        3
# FIRST_NAME                   3
# LAST_NAME                    3
# FIRST_COMMUNICATION_DATE     2
# INCOME                       2
# SALES_CHANNEL                1
# GENDER                       1
# Name: 1st_col, dtype: int64

# %%
# Active.groupby(by = 'SATELLITE',sort = True).count()

# %% [markdown]
# ### --------------------------------------------------- CHURN --------------------------------------------------------

# %%
churn.head(2)
# Out:
#   SITE_ACCOUNT_NUMBER ACCOUNT_STATUS  FIRST_COMMUNICATION_DATE  CHURN_DATE  \
# 0        AMR-53205840         Closed                     37274       38809
# 1        AMR-53383136         Closed                     37258       38907
#
#    UPGRADE_DATE  SERVICE_PLAN   MODEL  SALES_CHANNEL DIRECT_INDIRECT_CHANNEL  \
# 0       37989.0  Professional  DW6000            NaN                Indirect
# 1       38196.0            SO  DW6000  Retail/Others                Indirect
#
#        SALES_SOURCE      ...          SITE_TYPE_DESC WARRANTY_NAME  \
# 0        Perfect 10      ...        Broadband Remote           NaN
# 1  ValueElectronics      ...        Broadband Remote           NaN
#
#   MOST_RECENT_SALES_CHANNEL GENDER DATE_OF_BIRTH   AGE INCOME MARITAL_STATUS  \
# 0     Dealer-Generated Sale    2.0    27-10-1964  48.0      0              .
# 1            National Sales    NaN    22-10-1965  47.0      5              0
#
#   PRESENCE_OF_CHILDREN COMPUTER_OWNER
# 0                  NaN              N
# 1                  0.0              Y
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Dropping all variables' null rows which have less than 100 null values

# %%
churn.isnull().sum().sort_values(ascending =  False)
# Out:
# COMPUTER_OWNER               3243
# SALES_CHANNEL                2602
# FEEDBACK                     2028
# SERVICE_PLAN                 1482
# PRESENCE_OF_CHILDREN         1252
# GENDER                       1238
# SATELLITE                    1013
# UPGRADE_DATE                  879
# DIRECT_INDIRECT_CHANNEL       784
# MODEL                         710
# WARRANTY_NAME                 681
# SALES_SOURCE                  290
# MARITAL_STATUS                281
# SITE_TYPE_DESC                 63
# ZIPCODE                        45
# STATE                          45
# FIRST_NAME                     26
# MOST_RECENT_SALES_CHANNEL      21
# EMAIL_ADDRESS                  20
# ACCOUNT_STATUS                 15
# ADDRESS                         9
# AGE                             8
# COMPANY_SOURCE_NAME             8
# DATE_OF_BIRTH                   8
# LAST_NAME                       7
# FIRST_COMMUNICATION_DATE        0
# CITY                            0
# CHURN_DATE                      0
# INCOME                          0
# SITE_ACCOUNT_NUMBER             0
# dtype: int64

# %% [markdown]
# - Columns with less than 100 null values

# %%
churn[churn.columns[churn.isnull().sum() < 100]].columns
# Out:
# Index(['SITE_ACCOUNT_NUMBER', 'ACCOUNT_STATUS', 'FIRST_COMMUNICATION_DATE',
#        'CHURN_DATE', 'COMPANY_SOURCE_NAME', 'FIRST_NAME', 'LAST_NAME',
#        'ADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'EMAIL_ADDRESS',
#        'SITE_TYPE_DESC', 'MOST_RECENT_SALES_CHANNEL', 'DATE_OF_BIRTH', 'AGE',
#        'INCOME'],
#       dtype='object')

# %% [markdown]
# -  Dropping NA rows for columns with < 100 null values

# %%
churn.dropna(subset= churn[churn.columns[churn.isnull().sum() < 100]].columns,inplace=True)

# %% [markdown]
# #### After Dropping the rows

# %%
churn.isnull().sum().sort_values(ascending =  False)
# Out:
# COMPUTER_OWNER               3173
# SALES_CHANNEL                2554
# FEEDBACK                     1993
# SERVICE_PLAN                 1456
# PRESENCE_OF_CHILDREN         1230
# GENDER                       1209
# SATELLITE                     990
# UPGRADE_DATE                  868
# DIRECT_INDIRECT_CHANNEL       769
# MODEL                         697
# WARRANTY_NAME                 677
# SALES_SOURCE                  283
# MARITAL_STATUS                275
# FIRST_COMMUNICATION_DATE        0
# CHURN_DATE                      0
# FIRST_NAME                      0
# ACCOUNT_STATUS                  0
# COMPANY_SOURCE_NAME             0
# CITY                            0
# LAST_NAME                       0
# ADDRESS                         0
# STATE                           0
# ZIPCODE                         0
# EMAIL_ADDRESS                   0
# SITE_TYPE_DESC                  0
# MOST_RECENT_SALES_CHANNEL       0
# DATE_OF_BIRTH                   0
# AGE                             0
# INCOME                          0
# SITE_ACCOUNT_NUMBER             0
# dtype: int64

# %%
pandas_profiling.ProfileReport(Active)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>20 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>9827 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>160.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_AGE"><code>AGE</code></a> has a high cardinality: 63 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CITY"><code>CITY</code></a> has a high cardinality: 826 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_FIRST_NAME"><code>FIRST_NAME</code></a> has a high cardinality: 576 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_LAST_NAME"><code>LAST_NAME</code></a> has a high cardinality: 878 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_ACCOUNT_STATUS">ACCOUNT_STATUS<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>2</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0

# %% [markdown]
# ### Applying corrective measures based on Analysis done earlier - Pandas Profiling - S2

# %% [markdown]
# #### Dropping `ADDRESS`,`COMPUTER_OWNER`,`DATE_OF_BIRTH`,`EMAIL_ADDRESS`,`PRESENCE_OF_CHILDREN` columns
#
# - This is based on the results obtained from pandas profiling

# %%
churn.drop(columns=['ADDRESS','COMPUTER_OWNER','DATE_OF_BIRTH','EMAIL_ADDRESS','PRESENCE_OF_CHILDREN','MARITAL_STATUS'],inplace=True)

# %%
churn.shape
# Out:
# (9801, 24)

# %% [markdown]
# #### Fixing the remaining columns

# %%
pandas_profiling.ProfileReport(churn)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>25 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>9801 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>4.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1.9 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>200.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>16 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_ACCOUNT_STATUS"><code>ACCOUNT_STATUS</code></a> has constant value Closed <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_CHURN_DATE"><code>CHURN_DATE</code></a> is highly correlated with <a href="#pp_var_FIRST_COMMUNICATION_DATE"><code>FIRST_COMMUNICATION_DATE</code></a> (ρ = 0.96593) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_CITY"><code>CITY</code></a> has a high cardinality: 552 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_COMPANY_SOURCE_NAME"><code>COMPANY_SOURCE_NAME</code></a> has constant value HNS Customers <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_DIRECT_INDIRECT_CHANNEL"><code>DIRECT_INDIRECT_CHANNEL</code></a> has 769 / 7.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_FEEDBACK"><code>FEEDBACK</code></a> has 1993 / 20.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_FIRST_NAME"><code>FIRST_NAME</code></a> has a high cardinality: 1414 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_GENDER"><code>GENDER</code></a> has 1

# %%
cols = ['FEEDBACK','GENDER','INCOME','MODEL','SALES_CHANNEL','SALES_SOURCE',
        'SATELLITE','SERVICE_PLAN','WARRANTY_NAME']
for x in cols:
    print(Active[x].value_counts(dropna = False))
# Out:
# GOOD    4943
# BAD     3009
# NaN     1875
# Name: FEEDBACK, dtype: int64
#  1.0    4682
#  2.0    3891
# NaN     1254
# Name: GENDER, dtype: int64
# 0      2687
# 6      1510
# 7       998
# 4       950
# 5       866
# 3       664
# 8       586
# 9       459
# NaN     303
# A       189
# 2       168
# 1       155
# D       154
# C        96
# B        42
# Name: INCOME, dtype: int64
# HN7000S    4221
# HN9000     1960
# UNK         956
# NaN         657
# DW4020      648
# DW4000      631
# DW6000      506
# DW7000      248
# Name: MODEL, dtype: int64
# NaN              2855
# Sales Agents     1430
# Retail/others    1415
# Vars             1395
# Web orders       1369
# Call Center      1363
# Name: SALES_CHANNEL, dtype: int64
# TAG                                        1684
# Hughes Web Order                           1359
# RS&I                                       1042
# Perfect 10                                  841
# AmericanSat                                 802
# NaN                                         683
# NCC                                         582
# ACS                                         428
# LiveBridge Communications LLC               428
# InfoDish                                    360
# ACS Pre-Install                             292
# UNKNOWN                                     288
# Best Buy                                    287
# Verisign Web Ordering                       239
# MiniDish                                    119
# ValueElectronics                             92
# NRTC                                         62
# PEGASUS BROADBAND COMMUNICATIO               62
# PEGASUS                                      33
# D&H DISTRIBUTING                             25
# OROURKE BROTHERS                             16
# Hughes Internal Sales                        16
# Skylink (RSI572499)                          12
# Ridgeline USA LLC (RSI573306)                12
# Alpha Satellite (RSI568059)                  10
# Skylink                                      10
# SKYWALKER COMMUNICATIONS                     10
# Todays TV                                    10
# 0                                            10
# J & L AND SONS CUSTOM INSTALLATIONS INC       7
# Professional Satellites                       6
# Name: SALES_SOURCE, dtype: int64
# SPACEWAY3       1360
# SM5-VER-5K       874
# 0                828
# SM5-VER-15K      809
# G17-HOR-6K       705
# AM6-HOR-21K      658
# G17-HOR-2K       637
# SM5-VER-1K       552
# SM5-HOR-6K       417
# SM5-VER-7K       387
# NaN              380
# AM9-VER-2K       350
# SM5-HOR-14K      338
# HZN2-VER-4K      250
# G16-VER-15K      143
# G3C-VER-21K       98
# G16-VER-1K        78
# G16-HOR-8K        75
# HZN2-VER-8K       67
# G3C-VER-24K       67
# AM9-HOR-21K       60
# AM32-HOR-19K      54
# HZN-HOR-8K        50
# HZN-HOR-19K       49
# HZN-VER-23K       48
# G3C-VER-9K        42
# G16-VER-21K       42
# AM9-HOR-17K       34
# HZN-VER-6K        31
# G16-HOR-2K        31
# HZN2-VER-5K       31
# SM6-HOR-13K       29
# SM6-HOR-12K       27
# SM6-VER-2K        26
# AM32-HOR-7K       26
# AM9-HOR-19K       23
# G16-VER-2K        23
# HZN-VER-11K       22
# AM9-VER-22K       19
# G28-HOR-16K       17
# G26-HOR-14K       16
# AMC-HOR-10K       13
# G28-HOR-10K       12
# SM6-HOR-10K       12
# AM9-VER-2K         9
# AMC-VER-5K         8
# Name: SATELLITE, dtype: int64
# Proplus      1253
# Basic_Ltd    1248
# Basic        1239
# Elite        1236
# Power150     1231
# Home         1223
# NaN          1209
# Pro          1188
# Name: SERVICE_PLAN, dtype: int64
# 0                                                8379
# NaN                                               934
# EXPRESS REPAIR HOME WITH TERM                     292
# EXPRESS REPAIR HOME WITH COMMITMENT WITH TERM      50
# EXPRESS REPAIR BASIC                               48
# EXPRESS REPAIR HOME                                43
# EXPRESS REPAIR BUSINESS WITH TERM                  37
# EXPRESS REPAIR HOME W/O COMMITMENT WITH TERM       20
# SRVC ASSUR STD EXISTING CUST NO COMMIT             17
# SRVC ASSUR STD NEW CUST                             7
# Name: WARRANTY_NAME, dtype: int64

# %%
cols = ['FEEDBACK','GENDER','INCOME','MODEL','SALES_CHANNEL','SALES_SOURCE',
        'SATELLITE','SERVICE_PLAN','WARRANTY_NAME']

def cat_imputer(DF,column):
    for x in cols:
        DF['{0}'.format(x)] = DF['{0}'.format(x)].fillna(pd.Series(np.random.choice(DF['{0}'.format(x)].value_counts().index.tolist(), 
                                                          p= DF['{0}'.format(x)].value_counts(normalize= True).values.tolist(), size=len(DF))))

        DF['{0}'.format(x)] = DF['{0}'.format(x)].fillna(method = 'ffill')
        DF['{0}'.format(x)] = DF['{0}'.format(x)].apply(str)

# %%
cat_imputer(Active,cols)

# %%
for x in cols:
    print(Active[x].value_counts())

# %%
### Checking for remaining changes req - S3

# %% [markdown]
# #### Correl bw UPGRADE_DATE & FIRST_COMMUNICATION_DATE

# %%
pd.DataFrame(np.corrcoef(Active.UPGRADE_DATE,Active.FIRST_COMMUNICATION_DATE),
             columns= ['upgrade','first_Comm_date'])

# %%
plt.figure(figsize=[7,2])
x = Active[['UPGRADE_DATE','FIRST_COMMUNICATION_DATE']]
x.apply(lambda x:pd.to_datetime(x))

plt.plot(Active.UPGRADE_DATE)
plt.plot(Active.FIRST_COMMUNICATION_DATE)
plt.ylim(35000,50000)

# %% [markdown]
# #### Dropping Cols

# %% [markdown]
# - `COMPANY_SOURCE_NAME` has constant value HNS Customers Rejected - drop - done
# - `UPGRADE_DATE` is highly correlated with FIRST_COMMUNICATION_DATE (ρ = 0.99449) Rejected
# - `ZIPCODE` has a high cardinality: 896 distinct values Warning - drop - done
#
# - `WARRANTY_NAME` has 9260 values as 0 - drop - done

# %%
Active.drop(columns= ['COMPANY_SOURCE_NAME','ZIPCODE','WARRANTY_NAME','UPGRADE_DATE'],inplace=True)

# %%
Active.shape

# %%
pandas_profiling.ProfileReport(Active)

# %% [markdown]
# #### Outliers
#
# - All columns are categorical (nominal or ordinal) in nature so outlier detection in not an issue

# %% [markdown]
# #### Correlation

# %% [markdown]
# - Using Chi Square test for correlation

# %%
def chi_p_val(DF):
    li = []
    lt = []
    for x in DF.columns:
        scipy.stats.chisquare(DF[x].value_counts())
        for y in DF.columns:
            if x != y:
                f = x,y
                lt.append([x,y])
                con = pd.crosstab(DF[x],DF[y])
                chi_stat,p_value,Dof,cont_table = scipy.stats.chi2_contingency(con)
                li.extend([p_value])
            else:
                pass
    chi_P_value = pd.DataFrame(np.vstack(lt),columns=['1st_col','2nd_col'])

    chi_P_value['chi_square_p_value'] = li
    return chi_P_value

# %%
final = chi_p_val(Active)
final.head(2)

# %% [markdown]
# - Dependent Pair of vars for significane level of 0.05

# %%
final[final.chi_square_p_value < 0.05].sort_values(by = 'chi_square_p_value',ascending=False).head()

# %%
final[final.chi_square_p_value < 0.05]['1st_col'].value_counts()

# %% [markdown]
# ### ----------------

# %%
churn.head(2)

# %%
churn.shape

# %% [markdown]
# ## Modelling

# %%
# import numpy as np
# df = pd.DataFrame({'C1': np.random.choice(['C', 'B', 'A'], p=[0.16, 0.08, 0.76], 
#                                           size=1000)})
# df.loc[df.sample(frac=0.22).index] = np.nan

# df['C1'] = df['C1'].fillna(pd.Series(np.random.choice(df.C1.value_counts().index.tolist(), 
#                                                       p= df.C1.value_counts(normalize= True).values.tolist(), size=len(df))))

# df.C1.value_counts(normalize= True,dropna= False)

# df.C1.value_counts(normalize= True,dropna= False)
