# %%
import pandas as pd
import numpy as np

from PIL import Image

# %%
im = Image.open('C:/Users/Rohan/Desktop/Sydney-Opera-House.jpg')

im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0xB00DC623C8>

# %%
im.format,im.mode,im.size
# Out:
# ('JPEG', 'RGB', (640, 360))

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread('C:/Users/Rohan/Desktop/Sydney-Opera-House.jpg')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# uint8
# (360, 640, 3)

# %%
# load the image
print(im)
# convert image to numpy array
data = np.asarray(im)
# summarize shape
print(data.shape)
# create Pillow image
image2 = Image.fromarray(data)
# summarize image details
print(image2.format)
print(image2.mode)
print(image2.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0xB00DC623C8>
# (360, 640, 3)
# None
# RGB
# (640, 360)

# %%
Image.fromarray(data[:100])
# Out:
# <PIL.Image.Image image mode=RGB size=640x100 at 0xB00F9295C0>

# %%
plt.imshow(data[:,:100,:])

# %%
data_ = data.copy()

# %%
data_[:100,:,] = 255

# %%
plt.imshow(data_)

# %%
data_.shape
# Out:
# (360, 640, 3)

# %%
rows_range = np.arange(len(data))
cols_range = rows_range

# %%
plt.imshow(data_)
